# %%
import importlib

from models import robinhood
from utils.fetch_securties import *
from models.robinhood import *

# %%
df = fetch_securities(securities_dict)
df
# Out:
#   Ticker                   Name                 Sectors  \
# 0   AAPL             Apple Inc.              Technology
# 1   MSFT  Microsoft Corporation              Technology
# 2  GOOGL          Alphabet Inc.  Communication Services
# 3   AMZN       Amazon.com, Inc.       Consumer Cyclical
# 4   TSLA            Tesla, Inc.       Consumer Cyclical
# 5    VOO   Vanguard S&P 500 ETF                     N/A
# 6    NVO       Novo Nordisk A/S              Healthcare
# 7   TRAW     Traws Pharma, Inc.              Healthcare
# 8   PARA       Paramount Global  Communication Services
#
#                          Industry  Shares  Price Paid
# 0            Consumer Electronics   100.0      150.00
# 1       Software - Infrastructure    20.0      300.00
# 2  Internet Content & Information    10.0     2800.00
# 3                 Internet Retail     5.0     3500.00
# 4              Auto Manufacturers     8.0      700.00
# 5                             N/A   400.0      255.00
# 6                   Biotechnology   131.0       62.00
# 7                   Biotechnology     9.8        9.25
# 8                   Entertainment     9.8        9.25
