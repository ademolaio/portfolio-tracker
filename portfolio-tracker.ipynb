# %%
import importlib
from helper.fetch_securties import *
from models.robinhood import *

# %%
df = fetch_securities(securities_dict)
df
# Out:
#     Ticker                                  Name
# 0      AAL          American Airlines Group Inc.
# 1     ABSI                     Absci Corporation
# 2     ACCD                        Accolade, Inc.
# 3     ADPT  Adaptive Biotechnologies Corporation
# 4      AEO       American Eagle Outfitters, Inc.
# ..     ...                                   ...
# 117   VYNE                VYNE Therapeutics Inc.
# 118    WBA        Walgreens Boots Alliance, Inc.
# 119    WBX                          Wallbox N.V.
# 120   XCUR                         Exicure, Inc.
# 121    ZOM                        Zomedica Corp.
#
# [122 rows x 2 columns]

# %%
df_yes_options = df[df['Options Available'] == 'Yes']
df_yes_options
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Developer/Python/Ademola/Investment Fund/portfolio-tracker/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Options Available'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_yes_options = df[df['Options Available'] == 'Yes']
#       2 df_yes_options
#
# File ~/Developer/Python/Ademola/Investment Fund/portfolio-tracker/venv/lib/python3.11/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/Developer/Python/Ademola/Investment Fund/portfolio-tracker/venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Options Available'

# %%
sectors_options_count = df_yes_options.groupby('Sectors').size().reset_index(name='Count')
sectors_options_count
# Out:
#                    Sectors  Count
# 0   Communication Services      4
# 1        Consumer Cyclical     16
# 2       Consumer Defensive      5
# 3                   Energy      5
# 4       Financial Services      5
# 5               Healthcare     21
# 6              Industrials      7
# 7                      N/A      7
# 8              Real Estate     10
# 9               Technology     11
# 10               Utilities      1

# %%
analysts_ratings_count = df.groupby('Analysts Rating').size().reset_index(name='Count')
analysts_ratings_count
# Out:
#   Analysts Rating  Count
# 0             N/A     10
# 1             buy     54
# 2            hold     40
# 3            none      6
# 4      strong_buy      8
# 5    underperform      4

# %%
import pandas as pd

# With & Without Options Chain
bins = [0, 5, 10, 15, 20, 25, 30]
labels = ['4.99 and less', '5.00-9.99', '10.00-14.99', '15.00-19.99', '20.00-24.99', '25.00-29.99']
df['Price Value Group'] = pd.cut(df['Close Price'], bins=bins, labels=labels, right=False)
grouped = df.groupby('Price Value Group', observed=True).size().reset_index(name='Count')

grouped
# Out:
#   Price Value Group  Count
# 0     4.99 and less     66
# 1         5.00-9.99     17
# 2       10.00-14.99     12
# 3       15.00-19.99      7
# 4       20.00-24.99      8
# 5       25.00-29.99      5

# %%
import pandas as pd

# With Options Chain
bins = [0, 5, 10, 15, 20, 25, 30]
labels = ['4.99 and less', '5.00-9.99', '10.00-14.99', '15.00-19.99', '20.00-24.99', '25.00-29.99']
df['Price Value Group'] = pd.cut(df['Close Price'], bins=bins, labels=labels, right=False)
df_options = df[df['Options Available'] == 'Yes']
grouped = df_options.groupby('Price Value Group', observed=True).size().reset_index(name='Count')

grouped
# Out:
#   Price Value Group  Count
# 0     4.99 and less     39
# 1         5.00-9.99     17
# 2       10.00-14.99     12
# 3       15.00-19.99      7
# 4       20.00-24.99      8
# 5       25.00-29.99      2

# %%
df.dtypes
# Out:
# Ticker                  object
# Name                    object
# Exchange                object
# Security Type           object
# Sectors                 object
# Industry                object
# Shares                 float64
# Avg Cost               float64
# Cost Basis             float64
# Close Price            float64
# Market Value           float64
# Gain                   float64
# Analysts Rating         object
# Options Available       object
# Options Volume          object
# Implied Volatility      object
# Previous Close         float64
# Prices                  object
# Week 52 Range           object
# Opens                   object
# Bids                    object
# Asks                    object
# Market Cap              object
# PE Ratio                object
# EPS                     object
# Annual Dividends        object
# Dividend Yields         object
# Volumes                  int64
# Avg Volume               int64
# Betas                   object
# Declaration Dates       object
# Ex Dividend Dates       object
# Record Dates            object
# Payment Dates           object
# Earnings Dates          object
# Price Value Group     category
# dtype: object

# %%
df_filtered = df[df['Close Price'] <= 14.9900]
df_filtered
# Out:
#     Ticker                                  Name Exchange Security Type  \
# 0      AAL          American Airlines Group Inc.   NASDAQ        EQUITY
# 1     ABSI                     Absci Corporation   NASDAQ        EQUITY
# 2     ACCD                        Accolade, Inc.   NASDAQ        EQUITY
# 3     ADPT  Adaptive Biotechnologies Corporation   NASDAQ        EQUITY
# 5     AGNC                 AGNC Investment Corp.   NASDAQ        EQUITY
# ..     ...                                   ...      ...           ...
# 117   VYNE                VYNE Therapeutics Inc.   NASDAQ        EQUITY
# 118    WBA        Walgreens Boots Alliance, Inc.   NASDAQ        EQUITY
# 119    WBX                          Wallbox N.V.     NYSE        EQUITY
# 120   XCUR                         Exicure, Inc.   NASDAQ        EQUITY
# 121    ZOM                        Zomedica Corp.     NYSE        EQUITY
#
#          Sectors                     Industry  Shares  Avg Cost  Cost Basis  \
# 0    Industrials                     Airlines     1.0   11.0300     11.0300
# 1     Healthcare                Biotechnology     1.0    3.8900      3.8900
# 2     Healthcare  Health Information Services     1.0    3.8700      3.8700
# 3     Healthcare                Biotechnology     1.0    5.0200      5.0200
# 5    Real Estate              REIT - Mortgage   105.0   10.4300   1095.1500
# ..           ...                          ...     ...       ...         ...
# 117   Healthcare                Biotechnology     1.0    1.9000      1.9000
# 118   Healthcare     Pharmaceutical Retailers     5.0    9.1300     45.6500
# 119   Technology        Electronic Components     5.0    1.3500      6.7500
# 120   Healthcare                Biotechnology     1.0    1.9800      1.9800
# 121   Healthcare              Medical Devices    17.0    0.1447      2.4599
#
#      Close Price  ...  Dividend Yields   Volumes Avg Volume  Betas  \
# 0        11.5600  ...              N/A  30703352   36450326  1.433
# 1         3.9700  ...              N/A    544756    1330061  2.216
# 2         3.8600  ...              N/A    758403    1527714  2.002
# 3         5.0000  ...              N/A   1805328    1301192  1.433
# 5        10.5300  ...           0.1385  17086022   15586039  1.457
# ..           ...  ...              ...       ...        ...    ...
# 117       1.8400  ...              N/A     28572      40825  1.456
# 118       9.0600  ...           0.1174  27330175   20767950  0.683
# 119       1.2000  ...              N/A    231546     315690  2.125
# 120       3.6400  ...              N/A     46787    1387423   1.24
# 121       0.1325  ...              N/A   3022757    3011217   1.03
#
#     Declaration Dates Ex Dividend Dates  Record Dates Payment Dates  \
# 0                 N/A        1580774400           N/A           N/A
# 1                 N/A               N/A           N/A           N/A
# 2                 N/A               N/A           N/A           N/A
# 3                 N/A               N/A           N/A           N/A
# 5                 N/A        1727654400           N/A           N/A
# ..                ...               ...           ...           ...
# 117               N/A               N/A           N/A           N/A
# 118               N/A        1724198400           N/A           N/A
# 119               N/A               N/A           N/A           N/A
# 120               N/A               N/A           N/A           N/A
# 121               N/A               N/A           N/A           N/A
#
#     Earnings Dates Price Value Group
# 0              N/A       10.00-14.99
# 1              N/A     4.99 and less
# 2              N/A     4.99 and less
# 3              N/A         5.00-9.99
# 5              N/A       10.00-14.99
# ..             ...               ...
# 117            N/A     4.99 and less
# 118            N/A         5.00-9.99
# 119            N/A     4.99 and less
# 120            N/A     4.99 and less
# 121            N/A     4.99 and less
#
# [95 rows x 36 columns]

# %%
df['Options Volume'] = pd.to_numeric(df['Options Volume'], errors='coerce')


df_strategy_1 = df[~df['Industry'].str.contains('REIT', case=False, na=False) & (df['Close Price'] <= 14.9900) & (df['Options Available'] == 'Yes') & (df['Options Volume'] >= 1000.00)]
df_strategy_1
# Out:
#     Ticker                                      Name Exchange Security Type  \
# 0      AAL              American Airlines Group Inc.   NASDAQ        EQUITY
# 9      AMC          AMC Entertainment Holdings, Inc.     NYSE        EQUITY
# 12      BB                        BlackBerry Limited     NYSE        EQUITY
# 24    CHGG                               Chegg, Inc.     NYSE        EQUITY
# 25    CHPT                ChargePoint Holdings, Inc.     NYSE        EQUITY
# 26    CLOV          Clover Health Investments, Corp.   NASDAQ        EQUITY
# 37       F                        Ford Motor Company     NYSE        EQUITY
# 38    FFIE  Faraday Future Intelligent Electric Inc.   NASDAQ        EQUITY
# 39    FUBO                               fuboTV Inc.     NYSE        EQUITY
# 47     IEP                    Icahn Enterprises L.P.   NASDAQ        EQUITY
# 51    IOVA             Iovance Biotherapeutics, Inc.   NASDAQ        EQUITY
# 53    JBLU               JetBlue Airways Corporation   NASDAQ        EQUITY
# 58    LAZR                Luminar Technologies, Inc.   NASDAQ        EQUITY
# 59    LCID                         Lucid Group, Inc.   NASDAQ        EQUITY
# 63    LUNR                  Intuitive Machines, Inc.   NASDAQ        EQUITY
# 69     NIO                                  NIO Inc.     NYSE        EQUITY
# 74    OPEN                Opendoor Technologies Inc.   NASDAQ        EQUITY
# 77    PARA                          Paramount Global   NASDAQ        EQUITY
# 78    PATH                               UiPath Inc.     NYSE        EQUITY
# 79     PBR      Petróleo Brasileiro S.A. - Petrobras     NYSE        EQUITY
# 80    PLUG                           Plug Power Inc.   NASDAQ        EQUITY
# 83    PSNY        Polestar Automotive Holding UK PLC   NASDAQ        EQUITY
# 84    PTON                 Peloton Interactive, Inc.   NASDAQ        EQUITY
# 88    RIVN                   Rivian Automotive, Inc.   NASDAQ        EQUITY
# 89    RXRX           Recursion Pharmaceuticals, Inc.   NASDAQ        EQUITY
# 96    SNAP                                 Snap Inc.     NYSE        EQUITY
# 98    SOFI                   SoFi Technologies, Inc.   NASDAQ        EQUITY
# 118    WBA            Walgreens Boots Alliance, Inc.   NASDAQ        EQUITY
#
#                     Sectors                        Industry     Shares  \
# 0               Industrials                        Airlines    1.00000
# 9    Communication Services                   Entertainment    1.00000
# 12               Technology       Software - Infrastructure    1.00000
# 24       Consumer Defensive   Education & Training Services    1.00000
# 25        Consumer Cyclical                Specialty Retail    1.00000
# 26               Healthcare                Healthcare Plans    1.00000
# 37        Consumer Cyclical              Auto Manufacturers    1.00000
# 38        Consumer Cyclical              Auto Manufacturers    1.00000
# 39   Communication Services                    Broadcasting    1.00000
# 47                   Energy  Oil & Gas Refining & Marketing  174.25448
# 51               Healthcare                   Biotechnology    1.00000
# 53              Industrials                        Airlines    1.00000
# 58        Consumer Cyclical                      Auto Parts    3.00000
# 59        Consumer Cyclical              Auto Manufacturers  405.00000
# 63              Industrials             Aerospace & Defense    1.00000
# 69        Consumer Cyclical              Auto Manufacturers    1.00000
# 74              Real Estate            Real Estate Services    7.00000
# 77   Communication Services                   Entertainment    1.00000
# 78               Technology       Software - Infrastructure    1.00000
# 79                   Energy            Oil & Gas Integrated   72.00000
# 80              Industrials    Electrical Equipment & Parts    1.00000
# 83        Consumer Cyclical              Auto Manufacturers  100.00000
# 84        Consumer Cyclical                         Leisure    1.00000
# 88        Consumer Cyclical              Auto Manufacturers  100.00000
# 89               Healthcare                   Biotechnology    1.00000
# 96   Communication Services  Internet Content & Information    1.00000
# 98       Financial Services                 Credit Services    1.00000
# 118              Healthcare        Pharmaceutical Retailers    5.00000
#
#      Avg Cost   Cost Basis  Close Price  ...  Dividend Yields    Volumes  \
# 0       11.03    11.030000      11.5600  ...              N/A   30703352
# 9        4.44     4.440000       4.5000  ...              N/A    6691600
# 12       2.17     2.170000       2.5200  ...              N/A   26876514
# 24       1.79     1.790000       1.7700  ...              N/A    4170111
# 25       1.89     1.890000       1.3700  ...              N/A   10353661
# 26       2.59     2.590000       2.8200  ...              N/A    3207555
# 37      10.46    10.460000      10.7800  ...           0.0562   45073223
# 38       0.00     0.000000       2.7800  ...              N/A    6469977
# 39       1.39     1.390000       1.4600  ...              N/A    6898760
# 47      16.96  2955.355981      13.1100  ...           0.3037     861865
# 51      11.00    11.000000       9.6100  ...              N/A    3786830
# 53       6.49     6.490000       6.4200  ...              N/A   13468487
# 58       0.91     2.730000       0.9097  ...              N/A   31927122
# 59      14.26  5775.300000       3.5900  ...              N/A   32646576
# 63       7.55     7.550000       8.7800  ...              N/A   23686972
# 69       4.91     4.910000       6.5200  ...              N/A  176586899
# 74       2.27    15.890000       2.0700  ...              N/A   33156144
# 77      10.65    10.650000      10.7900  ...           0.0188    5208995
# 78      12.54    12.540000      12.8000  ...              N/A    4136587
# 79      15.20  1094.400000      14.5800  ...           0.1289   16959263
# 80       1.70     1.700000       2.2800  ...              N/A   63429002
# 83       2.26   226.000000       1.8300  ...              N/A    7663036
# 84       4.87     4.870000       4.8100  ...              N/A   11842255
# 88      27.98  2798.000000      11.6000  ...              N/A   35680263
# 89       7.16     7.160000       6.9800  ...              N/A    3438086
# 96      10.73    10.730000      10.8700  ...              N/A   25415710
# 98       7.75     7.750000       7.9500  ...              N/A   33139419
# 118      9.13    45.650000       9.0600  ...           0.1174   27330175
#
#     Avg Volume  Betas  Declaration Dates Ex Dividend Dates  Record Dates  \
# 0     36450326  1.433                N/A        1580774400           N/A
# 9     13731258   1.98                N/A        1583452800           N/A
# 12     5497455    N/A                N/A               N/A           N/A
# 24     3870422  1.319                N/A               N/A           N/A
# 25    13868839    1.7                N/A               N/A           N/A
# 26     7610234  2.139                N/A               N/A           N/A
# 37    59720092  1.635                N/A        1722988800           N/A
# 38     8830702   5.65                N/A               N/A           N/A
# 39    12540396    1.8                N/A               N/A           N/A
# 47     1204401  0.704                N/A        1724025600           N/A
# 51     6744404  0.626                N/A               N/A           N/A
# 53    16586817  1.908                N/A               N/A           N/A
# 58    17529858  1.611                N/A               N/A           N/A
# 59    38222773  1.059                N/A               N/A           N/A
# 63    13182374  0.255                N/A               N/A           N/A
# 69    50980187  1.831                N/A               N/A           N/A
# 74    29903900  2.688                N/A               N/A           N/A
# 77    11365571   1.77                N/A        1734307200           N/A
# 78    10495836   0.87                N/A               N/A           N/A
# 79    16332420  0.992                N/A        1724371200           N/A
# 80    39656311  1.782                N/A               N/A           N/A
# 83    12407565  2.151                N/A               N/A           N/A
# 84    16198026  2.041                N/A               N/A           N/A
# 88    35484250  2.069                N/A               N/A           N/A
# 89     5406369   0.81                N/A               N/A           N/A
# 96    25431207  1.005                N/A               N/A           N/A
# 98    41226274   1.71                N/A               N/A           N/A
# 118   20767950  0.683                N/A        1724198400           N/A
#
#     Payment Dates Earnings Dates Price Value Group
# 0             N/A            N/A       10.00-14.99
# 9             N/A            N/A     4.99 and less
# 12            N/A            N/A     4.99 and less
# 24            N/A            N/A     4.99 and less
# 25            N/A            N/A     4.99 and less
# 26            N/A            N/A     4.99 and less
# 37            N/A            N/A       10.00-14.99
# 38            N/A            N/A     4.99 and less
# 39            N/A            N/A     4.99 and less
# 47            N/A            N/A       10.00-14.99
# 51            N/A            N/A         5.00-9.99
# 53            N/A            N/A         5.00-9.99
# 58            N/A            N/A     4.99 and less
# 59            N/A            N/A     4.99 and less
# 63            N/A            N/A         5.00-9.99
# 69            N/A            N/A         5.00-9.99
# 74            N/A            N/A     4.99 and less
# 77            N/A            N/A       10.00-14.99
# 78            N/A            N/A       10.00-14.99
# 79            N/A            N/A       10.00-14.99
# 80            N/A            N/A     4.99 and less
# 83            N/A            N/A     4.99 and less
# 84            N/A            N/A     4.99 and less
# 88            N/A            N/A       10.00-14.99
# 89            N/A            N/A         5.00-9.99
# 96            N/A            N/A       10.00-14.99
# 98            N/A            N/A         5.00-9.99
# 118           N/A            N/A         5.00-9.99
#
# [28 rows x 36 columns]
