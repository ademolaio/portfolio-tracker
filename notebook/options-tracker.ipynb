# %%
from helper.fetch_securties import *
from data.options_25w01 import *

# %%
df = fetch_securities(securities_dict)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = fetch_securities(securities_dict)
#       2 df
#
# File ~/Developer/Python/Ademola/Investment Fund/portfolio-tracker/helper/fetch_securties.py:142, in fetch_securities(securities_dict)
#     139     earnings_dates.append(info.get('earningsDate', 'N/A'))
#     141 # Create the DataFrame with the Greeks and Implied Volatility included
# --> 142 df = pd.DataFrame({
#     143     'Ticker': securities_dict.keys(),
#     144     'Name': names,
#     145     'Exchange': exchanges,
#     146     'Security Type': security_types,
#     147     'Sectors': sectors,
#     148     'Industry': industries,
#     149     'Shares': shares,
#     150     'Avg Cost': avg_cost,
#     151     'Cost Basis': cost_basis,
#     152     'Close Price': close_prices,
#     153     'Market Value': market_values,
#     154     'Gain': gains,
#     155     'Analysts Rating': analysts_ratings,
#     156     'Options Available': options_available,
#     157     'Options Volume': options_volumes,
#     158     'Implied Volatility': implied_volatility,
#     159     'Previous Close': previous_closes,
#     160     'Prices': prices,
#     161     'Week 52 Range': week_52_ranges,
#     162     'Opens': opens,
#     163     'Bids': bids,
#     164     'Asks': asks,
#     165     'Market Cap': market_caps,
#     166     'PE Ratio': pe_ratios,
#     167     'EPS': eps,
#     168     'Annual Dividend': dividend_yields,
#     169     'Dividend Yield': dividend_yields,
#     170     'Volume': volumes,
#     171     'Avg Volume': avg_volumes,
#     172     'Betas': betas,
#     173     'Declaration Date': declaration_dates,
#     174     'Expiration Date': ex_dividend_dates,
#     175     'Record Date': record_dates,
#     176     'Payment Date': payment_dates,
#     177     'Earnings Date': earnings_dates,
#     178
#     179     })
#     181 return df
#
# File ~/Developer/Python/Ademola/Investment Fund/portfolio-tracker/venv/lib/python3.11/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File ~/Developer/Python/Ademola/Investment Fund/portfolio-tracker/venv/lib/python3.11/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/Developer/Python/Ademola/Investment Fund/portfolio-tracker/venv/lib/python3.11/site-packages/pandas/core/internals/construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~/Developer/Python/Ademola/Investment Fund/portfolio-tracker/venv/lib/python3.11/site-packages/pandas/core/internals/construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %%
df_yes_options = df[df['Options Available'] == 'Yes']
df_yes_options
# Out:
#    Ticker                                      Name Exchange Security Type  \
# 0     AAL              American Airlines Group Inc.   NASDAQ        EQUITY
# 1     AMC          AMC Entertainment Holdings, Inc.     NYSE        EQUITY
# 2      BB                        BlackBerry Limited     NYSE        EQUITY
# 3    BLNK                        Blink Charging Co.   NASDAQ        EQUITY
# 4    CHGG                               Chegg, Inc.     NYSE        EQUITY
# 5    CHPT                ChargePoint Holdings, Inc.     NYSE        EQUITY
# 6    CLOV          Clover Health Investments, Corp.   NASDAQ        EQUITY
# 7       F                        Ford Motor Company     NYSE        EQUITY
# 8    FFIE  Faraday Future Intelligent Electric Inc.   NASDAQ        EQUITY
# 9    FUBO                               fuboTV Inc.     NYSE        EQUITY
# 10   GOEV                                Canoo Inc.   NASDAQ        EQUITY
# 11   LAZR                Luminar Technologies, Inc.   NASDAQ        EQUITY
# 12   LCID                         Lucid Group, Inc.   NASDAQ        EQUITY
# 13   LYFT                                Lyft, Inc.   NASDAQ        EQUITY
# 14    NIO                                  NIO Inc.     NYSE        EQUITY
# 15    NOK                                 Nokia Oyj     NYSE        EQUITY
# 16   OPEN                Opendoor Technologies Inc.   NASDAQ        EQUITY
# 17   PATH                               UiPath Inc.     NYSE        EQUITY
# 18   PLUG                           Plug Power Inc.   NASDAQ        EQUITY
# 19   PSNY        Polestar Automotive Holding UK PLC   NASDAQ        EQUITY
# 20   PTON                 Peloton Interactive, Inc.   NASDAQ        EQUITY
# 21   RIVN                   Rivian Automotive, Inc.   NASDAQ        EQUITY
# 22   SNAP                                 Snap Inc.     NYSE        EQUITY
# 23   SOFI                   SoFi Technologies, Inc.   NASDAQ        EQUITY
# 24    WBD              Warner Bros. Discovery, Inc.   NASDAQ        EQUITY
#
#                    Sectors                        Industry  Shares  Avg Cost  \
# 0              Industrials                        Airlines     1.0     10.85
# 1   Communication Services                   Entertainment     1.0      4.44
# 2               Technology       Software - Infrastructure     1.0      2.17
# 3              Industrials      Engineering & Construction     1.0      2.17
# 4       Consumer Defensive   Education & Training Services     1.0      1.79
# 5        Consumer Cyclical                Specialty Retail     5.0      1.43
# 6               Healthcare                Healthcare Plans     1.0      2.59
# 7        Consumer Cyclical              Auto Manufacturers     5.0     10.65
# 8        Consumer Cyclical              Auto Manufacturers     1.0      0.00
# 9   Communication Services                    Broadcasting     1.0      1.39
# 10       Consumer Cyclical              Auto Manufacturers     3.0     38.49
# 11       Consumer Cyclical                      Auto Parts     3.0      0.91
# 12       Consumer Cyclical              Auto Manufacturers   405.0     14.26
# 13              Technology          Software - Application     0.0      0.00
# 14       Consumer Cyclical              Auto Manufacturers     1.0      4.91
# 15              Technology         Communication Equipment    57.0      4.45
# 16             Real Estate            Real Estate Services     7.0      2.27
# 17              Technology       Software - Infrastructure     1.0     12.54
# 18             Industrials    Electrical Equipment & Parts     3.0      1.94
# 19       Consumer Cyclical              Auto Manufacturers   100.0      2.26
# 20       Consumer Cyclical                         Leisure     1.0      4.87
# 21       Consumer Cyclical              Auto Manufacturers   100.0     27.98
# 22  Communication Services  Internet Content & Information     5.0     10.46
# 23      Financial Services                 Credit Services     1.0      7.75
# 24  Communication Services                   Entertainment     3.0      8.14
#
#     Cost Basis  Close Price  ...  Annual Dividend  Dividend Yield     Volume  \
# 0        10.85      10.7400  ...              N/A             N/A   28687723
# 1         4.44       4.3700  ...              N/A             N/A    4744975
# 2         2.17       2.4300  ...              N/A             N/A    8956729
# 3         2.17       1.6800  ...              N/A             N/A    2800699
# 4         1.79       1.6800  ...              N/A             N/A    3735619
# 5         7.15       1.3100  ...              N/A             N/A    8853654
# 6         2.59       3.5900  ...              N/A             N/A   25797042
# 7        53.25      10.4800  ...           0.0558          0.0558   51196280
# 8         0.00       2.9400  ...              N/A             N/A    5156312
# 9         1.39       1.4400  ...              N/A             N/A    6129227
# 10      115.47       0.9231  ...              N/A             N/A    2116387
# 11        2.73       0.8456  ...              N/A             N/A   19652781
# 12     5775.30       3.3400  ...              N/A             N/A   30166149
# 13        0.00      12.5400  ...              N/A             N/A    9114376
# 14        4.91       7.2100  ...              N/A             N/A  134298467
# 15      253.65       4.3900  ...           0.0322          0.0322   16630501
# 16       15.89       1.9000  ...              N/A             N/A   34447698
# 17       12.54      12.3300  ...              N/A             N/A    4521183
# 18        5.82       2.1600  ...              N/A             N/A   35996283
# 19      226.00       1.6800  ...              N/A             N/A    4366034
# 20        4.87       4.6200  ...              N/A             N/A   12167058
# 21     2798.00      10.6400  ...              N/A             N/A   29394801
# 22       52.30      10.8800  ...              N/A             N/A   22021345
# 23        7.75       7.7900  ...              N/A             N/A   27697556
# 24       24.42       7.9700  ...              N/A             N/A   23421075
#
#    Avg Volume  Betas  Declaration Date  Expiration Date Record Date  \
# 0    36783985  1.433               N/A       1580774400         N/A
# 1    12651026  1.980               N/A       1583452800         N/A
# 2     6052055  1.049               N/A              N/A         N/A
# 3     4689287  2.663               N/A              N/A         N/A
# 4     3833239  1.319               N/A              N/A         N/A
# 5    13101639  1.700               N/A              N/A         N/A
# 6     7589268  2.139               N/A              N/A         N/A
# 7    59720330  1.635               N/A       1722988800         N/A
# 8     8963235  5.650               N/A              N/A         N/A
# 9    12567958  1.800               N/A              N/A         N/A
# 10    3210741  1.288               N/A              N/A         N/A
# 11   18679961  1.611               N/A              N/A         N/A
# 12   38807744  1.059               N/A              N/A         N/A
# 13   14196644  2.046               N/A              N/A         N/A
# 14   57354774  1.831               N/A              N/A         N/A
# 15   16945985  0.730               N/A       1721692800         N/A
# 16   30784076  2.688               N/A              N/A         N/A
# 17   10288498  0.870               N/A              N/A         N/A
# 18   39146653  1.782               N/A              N/A         N/A
# 19   11429741  2.151               N/A              N/A         N/A
# 20   15497442  2.041               N/A              N/A         N/A
# 21   33293707  2.069               N/A              N/A         N/A
# 22   25720577  1.005               N/A              N/A         N/A
# 23   41355412  1.710               N/A              N/A         N/A
# 24   32614961  1.485               N/A              N/A         N/A
#
#    Payment Date Earnings Date
# 0           N/A           N/A
# 1           N/A           N/A
# 2           N/A           N/A
# 3           N/A           N/A
# 4           N/A           N/A
# 5           N/A           N/A
# 6           N/A           N/A
# 7           N/A           N/A
# 8           N/A           N/A
# 9           N/A           N/A
# 10          N/A           N/A
# 11          N/A           N/A
# 12          N/A           N/A
# 13          N/A           N/A
# 14          N/A           N/A
# 15          N/A           N/A
# 16          N/A           N/A
# 17          N/A           N/A
# 18          N/A           N/A
# 19          N/A           N/A
# 20          N/A           N/A
# 21          N/A           N/A
# 22          N/A           N/A
# 23          N/A           N/A
# 24          N/A           N/A
#
# [25 rows x 35 columns]

# %%
sectors_options_count = df_yes_options.groupby('Sectors').size().reset_index(name='Count')
sectors_options_count
# Out:
#                   Sectors  Count
# 0  Communication Services      4
# 1       Consumer Cyclical     10
# 2      Consumer Defensive      1
# 3      Financial Services      1
# 4              Healthcare      1
# 5             Industrials      3
# 6             Real Estate      1
# 7              Technology      4

# %%
analysts_ratings_count = df_yes_options.groupby('Analysts Rating').size().reset_index(name='Count')
analysts_ratings_count
# Out:
#   Analysts Rating  Count
# 0             buy      5
# 1            hold     19
# 2    underperform      1

# %%
df['Options Volume'] = pd.to_numeric(df['Options Volume'], errors='coerce')

df_strategy_1 = df[~df['Industry'].str.contains('REIT', case=False, na=False) & (df['Close Price'] <= 19.9900) & (df['Options Available'] == 'Yes') & (df['Options Volume'] >= 100.00)]
df_strategy_1
# Out:
#    Ticker                                      Name Exchange Security Type  \
# 0     AAL              American Airlines Group Inc.   NASDAQ        EQUITY
# 1     AMC          AMC Entertainment Holdings, Inc.     NYSE        EQUITY
# 2      BB                        BlackBerry Limited     NYSE        EQUITY
# 3    BLNK                        Blink Charging Co.   NASDAQ        EQUITY
# 4    CHGG                               Chegg, Inc.     NYSE        EQUITY
# 5    CHPT                ChargePoint Holdings, Inc.     NYSE        EQUITY
# 6    CLOV          Clover Health Investments, Corp.   NASDAQ        EQUITY
# 7       F                        Ford Motor Company     NYSE        EQUITY
# 8    FFIE  Faraday Future Intelligent Electric Inc.   NASDAQ        EQUITY
# 9    FUBO                               fuboTV Inc.     NYSE        EQUITY
# 10   GOEV                                Canoo Inc.   NASDAQ        EQUITY
# 12   LCID                         Lucid Group, Inc.   NASDAQ        EQUITY
# 13   LYFT                                Lyft, Inc.   NASDAQ        EQUITY
# 14    NIO                                  NIO Inc.     NYSE        EQUITY
# 15    NOK                                 Nokia Oyj     NYSE        EQUITY
# 16   OPEN                Opendoor Technologies Inc.   NASDAQ        EQUITY
# 17   PATH                               UiPath Inc.     NYSE        EQUITY
# 18   PLUG                           Plug Power Inc.   NASDAQ        EQUITY
# 19   PSNY        Polestar Automotive Holding UK PLC   NASDAQ        EQUITY
# 20   PTON                 Peloton Interactive, Inc.   NASDAQ        EQUITY
# 21   RIVN                   Rivian Automotive, Inc.   NASDAQ        EQUITY
# 22   SNAP                                 Snap Inc.     NYSE        EQUITY
# 23   SOFI                   SoFi Technologies, Inc.   NASDAQ        EQUITY
# 24    WBD              Warner Bros. Discovery, Inc.   NASDAQ        EQUITY
#
#                    Sectors                        Industry  Shares  Avg Cost  \
# 0              Industrials                        Airlines     1.0     10.85
# 1   Communication Services                   Entertainment     1.0      4.44
# 2               Technology       Software - Infrastructure     1.0      2.17
# 3              Industrials      Engineering & Construction     1.0      2.17
# 4       Consumer Defensive   Education & Training Services     1.0      1.79
# 5        Consumer Cyclical                Specialty Retail     5.0      1.43
# 6               Healthcare                Healthcare Plans     1.0      2.59
# 7        Consumer Cyclical              Auto Manufacturers     5.0     10.65
# 8        Consumer Cyclical              Auto Manufacturers     1.0      0.00
# 9   Communication Services                    Broadcasting     1.0      1.39
# 10       Consumer Cyclical              Auto Manufacturers     3.0     38.49
# 12       Consumer Cyclical              Auto Manufacturers   405.0     14.26
# 13              Technology          Software - Application     0.0      0.00
# 14       Consumer Cyclical              Auto Manufacturers     1.0      4.91
# 15              Technology         Communication Equipment    57.0      4.45
# 16             Real Estate            Real Estate Services     7.0      2.27
# 17              Technology       Software - Infrastructure     1.0     12.54
# 18             Industrials    Electrical Equipment & Parts     3.0      1.94
# 19       Consumer Cyclical              Auto Manufacturers   100.0      2.26
# 20       Consumer Cyclical                         Leisure     1.0      4.87
# 21       Consumer Cyclical              Auto Manufacturers   100.0     27.98
# 22  Communication Services  Internet Content & Information     5.0     10.46
# 23      Financial Services                 Credit Services     1.0      7.75
# 24  Communication Services                   Entertainment     3.0      8.14
#
#     Cost Basis  Close Price  ...  Annual Dividend  Dividend Yield     Volume  \
# 0        10.85      10.7400  ...              N/A             N/A   28687723
# 1         4.44       4.3700  ...              N/A             N/A    4744975
# 2         2.17       2.4300  ...              N/A             N/A    8956729
# 3         2.17       1.6800  ...              N/A             N/A    2800699
# 4         1.79       1.6800  ...              N/A             N/A    3735619
# 5         7.15       1.3100  ...              N/A             N/A    8853654
# 6         2.59       3.5900  ...              N/A             N/A   25797042
# 7        53.25      10.4800  ...           0.0558          0.0558   51196280
# 8         0.00       2.9400  ...              N/A             N/A    5156312
# 9         1.39       1.4400  ...              N/A             N/A    6129227
# 10      115.47       0.9231  ...              N/A             N/A    2116387
# 12     5775.30       3.3400  ...              N/A             N/A   30166149
# 13        0.00      12.5400  ...              N/A             N/A    9114376
# 14        4.91       7.2100  ...              N/A             N/A  134298467
# 15      253.65       4.3900  ...           0.0322          0.0322   16630501
# 16       15.89       1.9000  ...              N/A             N/A   34447698
# 17       12.54      12.3300  ...              N/A             N/A    4521183
# 18        5.82       2.1600  ...              N/A             N/A   35996283
# 19      226.00       1.6800  ...              N/A             N/A    4366034
# 20        4.87       4.6200  ...              N/A             N/A   12167058
# 21     2798.00      10.6400  ...              N/A             N/A   29394801
# 22       52.30      10.8800  ...              N/A             N/A   22021345
# 23        7.75       7.7900  ...              N/A             N/A   27697556
# 24       24.42       7.9700  ...              N/A             N/A   23421075
#
#    Avg Volume  Betas  Declaration Date  Expiration Date Record Date  \
# 0    36783985  1.433               N/A       1580774400         N/A
# 1    12651026  1.980               N/A       1583452800         N/A
# 2     6052055  1.049               N/A              N/A         N/A
# 3     4689287  2.663               N/A              N/A         N/A
# 4     3833239  1.319               N/A              N/A         N/A
# 5    13101639  1.700               N/A              N/A         N/A
# 6     7589268  2.139               N/A              N/A         N/A
# 7    59720330  1.635               N/A       1722988800         N/A
# 8     8963235  5.650               N/A              N/A         N/A
# 9    12567958  1.800               N/A              N/A         N/A
# 10    3210741  1.288               N/A              N/A         N/A
# 12   38807744  1.059               N/A              N/A         N/A
# 13   14196644  2.046               N/A              N/A         N/A
# 14   57354774  1.831               N/A              N/A         N/A
# 15   16945985  0.730               N/A       1721692800         N/A
# 16   30784076  2.688               N/A              N/A         N/A
# 17   10288498  0.870               N/A              N/A         N/A
# 18   39146653  1.782               N/A              N/A         N/A
# 19   11429741  2.151               N/A              N/A         N/A
# 20   15497442  2.041               N/A              N/A         N/A
# 21   33293707  2.069               N/A              N/A         N/A
# 22   25720577  1.005               N/A              N/A         N/A
# 23   41355412  1.710               N/A              N/A         N/A
# 24   32614961  1.485               N/A              N/A         N/A
#
#    Payment Date Earnings Date
# 0           N/A           N/A
# 1           N/A           N/A
# 2           N/A           N/A
# 3           N/A           N/A
# 4           N/A           N/A
# 5           N/A           N/A
# 6           N/A           N/A
# 7           N/A           N/A
# 8           N/A           N/A
# 9           N/A           N/A
# 10          N/A           N/A
# 12          N/A           N/A
# 13          N/A           N/A
# 14          N/A           N/A
# 15          N/A           N/A
# 16          N/A           N/A
# 17          N/A           N/A
# 18          N/A           N/A
# 19          N/A           N/A
# 20          N/A           N/A
# 21          N/A           N/A
# 22          N/A           N/A
# 23          N/A           N/A
# 24          N/A           N/A
#
# [24 rows x 35 columns]
